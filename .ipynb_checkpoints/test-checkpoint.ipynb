# %%
from Car_Insurance.training import CarInsurance

# Create a model instance
model = CarInsurance()

# Call the quote method
quote = model.quote_display(
    age=30,
    annual_km=15000,
    car_age=5,
    exp_years=10,
    num_accidents=1,
    vehicle_type="suv"
)

print(quote)
# Out:
# -----Car Insurance Quote-----
# Driver Age: 30
# Years of Experience: 10
# Previous Accidents: 1
# Annual Mileage: 15000 km
# Car Age: 5 years
# Vehicle Type: suv
#
# Estimated Car Insurance Premium: $521.97
# --------------------------------
